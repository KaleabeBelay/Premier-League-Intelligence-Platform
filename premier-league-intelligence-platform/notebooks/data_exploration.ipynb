# %%
import pandas as pd
df = pd.read_csv("../data/raw/25-26.csv")

# %%
df.head()
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth     4     2   H     1
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle     0     0   D     0
# 2  E0  16/08/2025  15:00     Brighton       Fulham     1     1   D     0
# 3  E0  16/08/2025  15:00   Sunderland     West Ham     3     0   H     0
# 4  E0  16/08/2025  15:00    Tottenham      Burnley     3     0   H     1
#
#    HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1     0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2     0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3     0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4     0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
#
#    AvgCAHA  BFECAHH  BFECAHA
# 0     1.76     2.14     1.86
# 1     1.74     2.14     1.86
# ...

# %%
df.tail()
# Out:
#     Div        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 354  E0  10/05/2026  14:00         Burnley  Aston Villa     2     2   D     1
# 355  E0  10/05/2026  14:00  Crystal Palace      Everton     2     2   D     1
# 356  E0  10/05/2026  14:00   Nott'm Forest    Newcastle     1     1   D     0
# 357  E0  10/05/2026  16:30        West Ham      Arsenal     0     1   A     0
# 358  E0  11/05/2026  20:00       Tottenham        Leeds     1     1   D     0
#
#      HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 354     1  ...     2.03     1.83    NaN    NaN     2.05     1.83     2.00
# 355     1  ...     2.03     1.83    NaN    NaN     2.03     1.83     1.96
# 356     0  ...     2.00     1.85    NaN    NaN     2.00     1.85     1.94
# 357     0  ...     1.80     2.05    NaN    NaN     1.90     2.05     1.80
# 358     0  ...     1.83     2.03    NaN    NaN     1.83     2.03     1.78
#
#      AvgCAHA  BFECAHH  BFECAHA
# ...

# %%
df.isnull().sum()
# Out:
# Div          0
# Date         0
# Time         0
# HomeTeam     0
# AwayTeam     0
#             ..
# MaxCAHA      0
# AvgCAHH      0
# AvgCAHA      0
# BFECAHH     22
# BFECAHA     22
# Length: 132, dtype: int64

# %%
df.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  359.000000  359.000000  359.000000  359.000000  359.000000  359.000000
# mean     1.518106    1.228412    0.685237    0.509749   13.766017   11.105850
# std      1.178997    1.092471    0.786463    0.750635    4.914448    4.601426
# min      0.000000    0.000000    0.000000    0.000000    1.000000    3.000000
# 25%      1.000000    0.000000    0.000000    0.000000   11.000000    8.000000
# 50%      1.000000    1.000000    1.000000    0.000000   14.000000   11.000000
# 75%      2.000000    2.000000    1.000000    1.000000   16.500000   14.000000
# max      5.000000    5.000000    3.000000    4.000000   35.000000   30.000000
#
#               HST         AST          HF          AF  ...    B365CAHH  \
# count  359.000000  359.000000  359.000000  359.000000  ...  359.000000
# mean     4.487465    3.857939   10.615599   11.066852  ...    1.918830
# ...

# %%
df.columns
# Out:
# Index(['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
#        'HTHG', 'HTAG',
#        ...
#        'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH', 'MaxCAHA',
#        'AvgCAHH', 'AvgCAHA', 'BFECAHH', 'BFECAHA'],
#       dtype='object', length=132)
